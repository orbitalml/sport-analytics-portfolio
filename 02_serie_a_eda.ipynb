# %%
import pandas as pd

# %%
serie_A_24_25 = pd.read_csv("I1.csv")

# %%
serie_A_24_25.head()
# Out:
#   Div        Date   Time HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0  I1  17/08/2024  17:30    Genoa       Inter     2     2   D     1     1
# 1  I1  17/08/2024  17:30    Parma  Fiorentina     1     1   D     1     0
# 2  I1  17/08/2024  19:45   Empoli       Monza     0     0   D     0     0
# 3  I1  17/08/2024  19:45    Milan      Torino     2     2   D     0     1
# 4  I1  18/08/2024  17:30  Bologna     Udinese     1     1   D     0     0
#
#    ... B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  AvgCAHA  \
# 0  ...     2.06      1.87   2.08   1.85     2.13     1.89     2.05     1.82
# 1  ...     2.07      1.86   2.05   1.88     2.07     1.91     2.01     1.84
# 2  ...     2.10      1.83   2.12   1.83     2.14     1.86     2.08     1.79
# 3  ...     1.89      2.04   1.88   2.04     1.92     2.10     1.84     2.02
# 4  ...     2.10      1.83   2.09   1.85     2.15     1.86     2.08     1.81
#
#    BFECAHH  BFECAHA
# 0     2.09     1.90
# 1     2.09     1.90
# 2     2.16     1.85
# 3     1.90     2.08
# 4     2.12     1.87
#
# [5 rows x 119 columns]

# %%
serie_A_24_25.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380 entries, 0 to 379
# Columns: 119 entries, Div to BFECAHA
# dtypes: float64(96), int64(16), object(7)
# memory usage: 353.4+ KB

# %%
serie_A_24_25.describe()
# Out:
#              FTHG        FTAG        HTHG        HTAG          HS          AS  \
# count  380.000000  380.000000  380.000000  380.000000  380.000000  380.000000
# mean     1.339474    1.221053    0.557895    0.557895   13.131579   10.923684
# std      1.143074    1.134063    0.750947    0.761415    5.169788    4.558267
# min      0.000000    0.000000    0.000000    0.000000    3.000000    1.000000
# 25%      0.000000    0.000000    0.000000    0.000000    9.000000    7.000000
# 50%      1.000000    1.000000    0.000000    0.000000   12.000000   11.000000
# 75%      2.000000    2.000000    1.000000    1.000000   16.000000   14.000000
# max      6.000000    6.000000    5.000000    5.000000   30.000000   26.000000
#
#               HST         AST          HF          AF  ...    B365CAHH  \
# count  380.000000  380.000000  380.000000  380.000000  ...  380.000000
# mean     4.289474    3.781579   12.184211   12.818421  ...    1.949263
# std      2.246168    2.227716    4.094241    4.244652  ...    0.104589
# min      0.000000    0.000000    1.000000    3.000000  ...    1.680000
# 25%      3.000000    2.000000    9.000000   10.000000  ...    1.870000
# 50%      4.000000    3.000000   12.000000   13.000000  ...    1.950000
# 75%      6.000000    5.000000   15.000000   15.000000  ...    2.040000
# max     11.000000   11.000000   26.000000   29.000000  ...    2.160000
#
#          B365CAHA       PCAHH       PCAHA     MaxCAHH     MaxCAHA     AvgCAHH  \
# count  380.000000  380.000000  380.000000  380.000000  380.000000  380.000000
# mean     1.957237    1.959421    1.969474    1.996579    2.002421    1.929237
# std      0.098541    0.101116    0.100842    0.098444    0.102195    0.093231
# min      1.670000    1.750000    1.760000    1.810000    1.800000    1.740000
# 25%      1.870000    1.880000    1.880000    1.920000    1.910000    1.850000
# 50%      1.965000    1.950000    1.970000    1.990000    2.000000    1.925000
# 75%      2.050000    2.050000    2.060000    2.080000    2.080000    2.010000
# max      2.150000    2.210000    2.200000    2.250000    2.250000    2.150000
#
#           AvgCAHA     BFECAHH     BFECAHA
# count  380.000000  380.000000  380.000000
# mean     1.931868    1.991053    1.997895
# std      0.093724    0.100497    0.101038
# min      1.730000    1.760000    1.750000
# 25%      1.850000    1.910000    1.910000
# 50%      1.930000    1.990000    1.995000
# 75%      2.010000    2.070000    2.080000
# max      2.170000    2.310000    2.290000
#
# [8 rows x 112 columns]

# %%
tot_matches = serie_A_24_25.shape [0]
tot_matches
# Out:
# 380

# %%
serie_A_24_25.columns[:10]
# Out:
# Index(['Div', 'Date', 'Time', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR',
#        'HTHG', 'HTAG'],
#       dtype='object')

# %%
cols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG', 'HTAG']
df = serie_A_24_25[cols]
df.head()
# Out:
#          Date HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  HTAG
# 0  17/08/2024    Genoa       Inter     2     2   D     1     1
# 1  17/08/2024    Parma  Fiorentina     1     1   D     1     0
# 2  17/08/2024   Empoli       Monza     0     0   D     0     0
# 3  17/08/2024    Milan      Torino     2     2   D     0     1
# 4  18/08/2024  Bologna     Udinese     1     1   D     0     0

# %%
teams = df.HomeTeam.unique()

# Calculating total gols for each team
total_goal = {}
for team in teams:
    home = df.loc[df.HomeTeam == team]
    home_goal = home.FTHG.sum()
    away = df.loc[df.AwayTeam == team]
    away_goal = away.FTAG.sum()
    total_goal[team] = int(home_goal+away_goal)

# Team with max/min gols
goal_per_team = pd.Series(total_goal)
print("Max gol:", goal_per_team.idxmax(), "-", goal_per_team[goal_per_team.idxmax()])
print("Min gol:", goal_per_team.idxmin(), "-", goal_per_team[goal_per_team.idxmin()])

# Average gols per match
goal_per_match = (df.FTHG + df.FTAG).mean()
print ("Average gol per match: ",round(goal_per_match, 2))

# Result (1/2/X) percentage
result = df.FTR.value_counts(normalize = True)
print ("Result 1", round(result.H,3)*100,"%")
print ("Result 2", round(result.A,3)*100,"%")
print ("Result X", round(result.D,3)*100,"%")

# More frequent results
results = (df.FTHG.astype(str) + " - " + df.FTAG.astype(str))
print("Most frequent results:\n", results.value_counts().head(3))

# Matches with at least one team @0 gols
print("Matches with at least one team @0 gols:", ((df.FTHG == 0) | (df.FTAG == 0)).sum(), "(",round((((df.FTHG == 0) | (df.FTAG == 0)).sum())/tot_matches*100,2),"%)")
# Out:
# Max gol: Inter - 79
# Min gol: Lecce - 27
# Average gol per match:  2.56
# Result 1 39.7 %
# Result 2 31.8 %
# Result X 28.4 %
# Most frequent results:
#  1 - 1    53
# 1 - 0    38
# 2 - 1    36
# Name: count, dtype: int64
# Matches with at least one team @0 gols: 184 ( 48.42 %)

# %%
import matplotlib.pyplot as plt

# %%
total_win = {}
for team in teams:
    home_win = ((df.HomeTeam == team) & (df.FTR == "H")).sum()
    away_win = ((df.AwayTeam == team) & (df.FTR == "A")).sum()
    total_win[team] = int(home_win + away_win)
total_win
# Out:
# {'Genoa': 10,
#  'Parma': 7,
#  'Empoli': 6,
#  'Milan': 18,
#  'Bologna': 16,
#  'Verona': 10,
#  'Cagliari': 9,
#  'Lazio': 18,
#  'Lecce': 8,
#  'Juventus': 18,
#  'Udinese': 12,
#  'Inter': 24,
#  'Monza': 3,
#  'Fiorentina': 19,
#  'Torino': 10,
#  'Napoli': 24,
#  'Roma': 20,
#  'Venezia': 5,
#  'Como': 13,
#  'Atalanta': 22}

# %%
vittorie_series = pd.Series(total_win).sort_values(ascending=False)

plt.figure(figsize=(12, 6))
plt.bar(vittorie_series.index, vittorie_series.values)
plt.title("Vittorie per squadra — Serie A 2024-25")
plt.xlabel("Squadra")
plt.ylabel("Vittorie")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.savefig("vittorie_squadre.png")
plt.show()
